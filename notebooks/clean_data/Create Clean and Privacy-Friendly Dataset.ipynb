# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
raw_df = pd.read_json("../../data/raw_data/base_18032019.json")

# %%
raw_df.columns
# Out:
# Index(['fields', 'model', 'pk'], dtype='object')

# %%
def extract_flatten_dataframe(df, column, meta_list):
    df_fields = json_normalize(data=df[column], meta=meta_list)
    df_fields.index = df.index
    return df_fields.join(df, how="outer")

# %% [markdown]
# # Clean data

# %% [markdown]
# ## drop models that won't be useful for the analysis

# %%
exclude_models = ["oauth2_provider.application", "oauth2_provider.refreshtoken", "oauth2_provider.accesstoken",
                 "themes.themes", "security.security", "mailsender.mailsender"]
cleaned_raw_df = raw_df[~raw_df["model"].isin(exclude_models)]

# %%
df_extracted = extract_flatten_dataframe(cleaned_raw_df, "fields", None)

# %%
df_extracted.columns
# Out:
# Index(['_my_subclass', 'action', 'active', 'all_students', 'alt_img', 'answer',
#        'begin_date', 'brief_description', 'categories', 'category',
#        ...
#        'user_quest', 'user_two', 'username', 'value', 'viewed', 'visible',
#        'xls_data', 'fields', 'model', 'pk'],
#       dtype='object', length=178)

# %%
drop_columns = ["username", "fields", "alt_img", "context.user_name", "social_name", 
                "user_email", "last_name", "question_img", "password", "csv_data", "xls_data", "image",
                "session_data", "user", "context.new_creator", "content", "context.new_creator_user",
               "ran_at_time", "email", "user_email", "context.student", "context.user_email", "device_id"]

# %%
df_cleaned = df_extracted.drop(columns=drop_columns)

# %%
for column in df_cleaned.columns:
    print(column)
# Out:
# _my_subclass
# action
# active
# all_students
# answer
# begin_date
# brief_description
# categories
# category
# code
# comment
# component
# context
# context.bulletin_id
# context.bulletin_name
# context.bulletin_slug
# context.category_id
# context.category_name
# context.category_slug
# context.comment_id
# context.condition
# context.dependencies
# context.goals_id
# context.goals_name
# context.goals_slug
# context.group_id
# context.group_name
# context.group_slug
# context.history_page
# context.is_correct
# context.new_slug
# context.new_title
# context.notification
# context.notification_id
# context.pdffile_id
# context.pdffile_name
# context.pdffile_slug
# context.post_id
# context.post_space_id
# context.post_space_name
# context.post_space_slug
# context.question_content
# context.question_id
# context.questionary_id
# context.questionary_name
# context.questionary_slug
# context.resource_id
# context.resource_name
# context.resource_slug
# context.search_by
# context.search_for
# context.searched
# context.subject_id
# context.subject_name
# context.subject_slug
# context.talk_id
# context.time_to_answer
# context.timestamp_end
# context.timestamp_start
# context.topic_id
# context.topic_name
# context.topic_slug
# context.user_id
# context.view_page
# context.webconference_finish
# context.webconference_id
# context.webconference_init
# context.webconference_name
# context.webconference_online
# context.webconference_slug
# context.webconference_view
# context.webpage_id
# context.webpage_name
# context.webpage_slug
# context.ytvideo_id
# context.ytvideo_name
# context.ytvideo_slug
# coordinators
# create_date
# created_at
# creation_date
# data_end
# data_ini
# date_created
# date_viewed
# datetime
# description
# description_brief
# domain
# edited
# end_date
# end_time
# enunciado
# expire_date
# file
# file_content
# goal
# groups
# indicators
# init_date
# is_active
# is_correct
# is_staff
# is_success
# is_superuser
# item
# last_login
# last_update
# level
# limit_date
# limit_submission_date
# max_upload_size
# message
# meta
# modified_date
# n_questions
# name
# order
# participants
# post
# presentation
# professor
# question
# questionary
# ref_value
# registration_id
# repository
# resource
# show_email
# show_window
# slug
# space
# start_time
# student
# students
# subject
# subscribe_begin
# subscribe_end
# tags
# talk
# task
# text
# topic
# type
# update_date
# url
# user_id
# user_one
# user_permissions
# user_quest
# user_two
# value
# viewed
# visible
# model
# pk

# %%
df_cleaned["context.timestamp_end"].value_counts()
# Out:
# 1549897206    301
# 1542315016    270
# 1542155773    248
# 1541802642    240
# 1541802643    194
# 1542315017    193
# 1542026526    155
# 1542304122    155
# 1542027382    154
# 1541803863    150
# 1542154953    146
# 1542166959    143
# 1541813396    135
# 1549887746    128
# 1541787923    112
# 1542304121    100
# 1549887128     98
# 1544058652     93
# 1541802641     89
# 1544464922     86
# 1549807071     83
# 1542301583     82
# 1541639233     80
# 1544291973     78
# 1542250988     78
# 1542026739     76
# 1542250987     76
# 1544277469     76
# 1544055012     70
# 1544449373     65
#              ...
# 1544144333      1
# 1543931924      1
# 1543714863      1
# 1542323853      1
# 1544367797      1
# 1548079157      1
# 1544909447      1
# 1548092412      1
# 1543349432      1
# 1547468278      1
# 1549899938      1
# 1541471395      1
# 1552597037      1
# 1548444319      1
# 1541606949      1
# 1550427857      1
# 1552161509      1
# 1542199432      1
# 1547553626      1
# 1549810848      1
# 1540234782      1
# 1544734408      1
# 1549803910      1
# 1541779800      1
# 1549898972      1
# 1549830594      1
# 1551270404      1
# 1542379121      1
# 1548965905      1
# 1552880801      1
# Name: context.timestamp_end, Length: 51078, dtype: int64

# %%
df_cleaned[df_cleaned["context.condition"] == "session_expire"]
# Out:
#        _my_subclass  action  active  all_students  answer begin_date  \
# 130677          NaN  logout    True          True     NaN        NaT
# 130974          NaN  logout    True          True     NaN        NaT
# 131007          NaN  logout    True          True     NaN        NaT
# 131022          NaN  logout    True          True     NaN        NaT
# 131210          NaN  logout    True          True     NaN        NaT
# 131626          NaN  logout    True          True     NaN        NaT
# 131762          NaN  logout    True          True     NaN        NaT
# 131937          NaN  logout    True          True     NaN        NaT
# 132273          NaN  logout    True          True     NaN        NaT
# 132880          NaN  logout    True          True     NaN        NaT
# 132889          NaN  logout    True          True     NaN        NaT
# 133031          NaN  logout    True          True     NaN        NaT
# 133106          NaN  logout    True          True     NaN        NaT
# 133433          NaN  logout    True          True     NaN        NaT
# 133493          NaN  logout    True          True     NaN        NaT
# 133512          NaN  logout    True          True     NaN        NaT
# 133934          NaN  logout    True          True     NaN        NaT
# 133967          NaN  logout    True          True     NaN        NaT
# 134000          NaN  logout    True          True     NaN        NaT
# 134076          NaN  logout    True          True     NaN        NaT
# 134167          NaN  logout    True          True     NaN        NaT
# 134229          NaN  logout    True          True     NaN        NaT
# 135295          NaN  logout    True          True     NaN        NaT
# 135400          NaN  logout    True          True     NaN        NaT
# 135402          NaN  logout    True          True     NaN        NaT
# 135403          NaN  logout    True          True     NaN        NaT
# 135404          NaN  logout    True          True     NaN        NaT
# 135406          NaN  logout    True          True     NaN        NaT
# 135868          NaN  logout    True          True     NaN        NaT
# 135878          NaN  logout    True          True     NaN        NaT
# ...             ...     ...     ...           ...     ...        ...
# 259613          NaN  logout    True          True     NaN        NaT
# 259619          NaN  logout    True          True     NaN        NaT
# 259647          NaN  logout    True          True     NaN        NaT
# 259650          NaN  logout    True          True     NaN        NaT
# 259653          NaN  logout    True          True     NaN        NaT
# 259673          NaN  logout    True          True     NaN        NaT
# 259676          NaN  logout    True          True     NaN        NaT
# 259682          NaN  logout    True          True     NaN        NaT
# 259694          NaN  logout    True          True     NaN        NaT
# 259695          NaN  logout    True          True     NaN        NaT
# 259696          NaN  logout    True          True     NaN        NaT
# 259697          NaN  logout    True          True     NaN        NaT
# 259698          NaN  logout    True          True     NaN        NaT
# 259709          NaN  logout    True          True     NaN        NaT
# 259713          NaN  logout    True          True     NaN        NaT
# 259721          NaN  logout    True          True     NaN        NaT
# 259722          NaN  logout    True          True     NaN        NaT
# 259730          NaN  logout    True          True     NaN        NaT
# 259747          NaN  logout    True          True     NaN        NaT
# 259797          NaN  logout    True          True     NaN        NaT
# 259798          NaN  logout    True          True     NaN        NaT
# 259809          NaN  logout    True          True     NaN        NaT
# 259859          NaN  logout    True          True     NaN        NaT
# 259869          NaN  logout    True          True     NaN        NaT
# 259870          NaN  logout    True          True     NaN        NaT
# 259874          NaN  logout    True          True     NaN        NaT
# 259876          NaN  logout    True          True     NaN        NaT
# 259888          NaN  logout    True          True     NaN        NaT
# 259893          NaN  logout    True          True     NaN        NaT
# 259898          NaN  logout    True          True     NaN        NaT
#
#        brief_description categories  category code  ... user_id user_one  \
# 130677               NaN        NaN       NaN  NaN  ...     1.0      NaN
# 130974               NaN        NaN       NaN  NaN  ...     1.0      NaN
# 131007               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 131022               NaN        NaN       NaN  NaN  ...     1.0      NaN
# 131210               NaN        NaN       NaN  NaN  ...     1.0      NaN
# 131626               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 131762               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 131937               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 132273               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 132880               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 132889               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 133031               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 133106               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 133433               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 133493               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 133512               NaN        NaN       NaN  NaN  ...     2.0      NaN
# 133934               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 133967               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 134000               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 134076               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 134167               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 134229               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 135295               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 135400               NaN        NaN       NaN  NaN  ...     4.0      NaN
# 135402               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 135403               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 135404               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 135406               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 135868               NaN        NaN       NaN  NaN  ...     3.0      NaN
# 135878               NaN        NaN       NaN  NaN  ...     3.0      NaN
# ...                  ...        ...       ...  ...  ...     ...      ...
# 259613               NaN        NaN       NaN  NaN  ...    18.0      NaN
# 259619               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259647               NaN        NaN       NaN  NaN  ...    12.0      NaN
# 259650               NaN        NaN       NaN  NaN  ...    22.0      NaN
# 259653               NaN        NaN       NaN  NaN  ...    46.0      NaN
# 259673               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259676               NaN        NaN       NaN  NaN  ...    76.0      NaN
# 259682               NaN        NaN       NaN  NaN  ...    39.0      NaN
# 259694               NaN        NaN       NaN  NaN  ...    35.0      NaN
# 259695               NaN        NaN       NaN  NaN  ...    75.0      NaN
# 259696               NaN        NaN       NaN  NaN  ...    75.0      NaN
# 259697               NaN        NaN       NaN  NaN  ...    32.0      NaN
# 259698               NaN        NaN       NaN  NaN  ...    12.0      NaN
# 259709               NaN        NaN       NaN  NaN  ...    86.0      NaN
# 259713               NaN        NaN       NaN  NaN  ...    69.0      NaN
# 259721               NaN        NaN       NaN  NaN  ...    30.0      NaN
# 259722               NaN        NaN       NaN  NaN  ...    45.0      NaN
# 259730               NaN        NaN       NaN  NaN  ...    45.0      NaN
# 259747               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259797               NaN        NaN       NaN  NaN  ...    45.0      NaN
# 259798               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259809               NaN        NaN       NaN  NaN  ...    45.0      NaN
# 259859               NaN        NaN       NaN  NaN  ...    86.0      NaN
# 259869               NaN        NaN       NaN  NaN  ...    75.0      NaN
# 259870               NaN        NaN       NaN  NaN  ...    48.0      NaN
# 259874               NaN        NaN       NaN  NaN  ...    45.0      NaN
# 259876               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259888               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259893               NaN        NaN       NaN  NaN  ...    31.0      NaN
# 259898               NaN        NaN       NaN  NaN  ...    31.0      NaN
#
#        user_permissions  user_quest user_two value  viewed visible    model  \
# 130677              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 130974              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131007              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131022              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131210              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131626              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131762              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 131937              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 132273              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 132880              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 132889              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133031              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133106              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133433              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133493              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133512              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133934              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 133967              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 134000              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 134076              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 134167              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 134229              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135295              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135400              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135402              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135403              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135404              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135406              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135868              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 135878              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# ...                 ...         ...      ...   ...     ...     ...      ...
# 259613              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259619              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259647              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259650              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259653              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259673              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259676              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259682              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259694              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259695              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259696              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259697              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259698              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259709              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259713              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259721              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259722              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259730              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259747              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259797              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259798              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259809              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259859              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259869              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259870              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259874              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259876              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259888              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259893              NaN         NaN      NaN   NaN     NaN     NaN  log.log
# 259898              NaN         NaN      NaN   NaN     NaN     NaN  log.log
#
#             pk
# 130677       2
# 130974     299
# 131007     332
# 131022     347
# 131210     535
# 131626     951
# 131762    1087
# 131937    1262
# 132273    1598
# 132880    2205
# 132889    2214
# 133031    2356
# 133106    2431
# 133433    2758
# 133493    2818
# 133512    2837
# 133934    3259
# 133967    3292
# 134000    3325
# 134076    3401
# 134167    3492
# 134229    3554
# 135295    4620
# 135400    4725
# 135402    4727
# 135403    4728
# 135404    4729
# 135406    4731
# 135868    5193
# 135878    5203
# ...        ...
# 259613  128938
# 259619  128944
# 259647  128972
# 259650  128975
# 259653  128978
# 259673  128998
# 259676  129001
# 259682  129007
# 259694  129019
# 259695  129020
# 259696  129021
# 259697  129022
# 259698  129023
# 259709  129034
# 259713  129038
# 259721  129046
# 259722  129047
# 259730  129055
# 259747  129072
# 259797  129122
# 259798  129123
# 259809  129134
# 259859  129184
# 259869  129194
# 259870  129195
# 259874  129199
# 259876  129201
# 259888  129213
# 259893  129218
# 259898  129223
#
# [4846 rows x 157 columns]

# %% [markdown]
# # Send cleaned data without privacy concern variables

# %%
df_cleaned.dtypes
# Out:
# _my_subclass              object
# action                    object
# active                    object
# all_students              object
# answer                   float64
# begin_date                object
# brief_description         object
# categories                object
# category                 float64
# code                      object
# comment                   object
# component                 object
# context                   object
# context.bulletin_id      float64
# context.bulletin_name     object
# context.bulletin_slug     object
# context.category_id      float64
# context.category_name     object
# context.category_slug     object
# context.comment_id        object
# context.condition         object
# context.dependencies      object
# context.goals_id         float64
# context.goals_name        object
# context.goals_slug        object
# context.group_id         float64
# context.group_name        object
# context.group_slug        object
# context.history_page      object
# context.is_correct        object
#                           ...
# repository                object
# resource                  object
# show_email               float64
# show_window               object
# slug                      object
# space                    float64
# start_time                object
# student                  float64
# students                  object
# subject                  float64
# subscribe_begin           object
# subscribe_end             object
# tags                      object
# talk                     float64
# task                     float64
# text                      object
# topic                    float64
# type                      object
# update_date               object
# url                       object
# user_id                  float64
# user_one                 float64
# user_permissions          object
# user_quest               float64
# user_two                 float64
# value                    float64
# viewed                    object
# visible                   object
# model                     object
# pk                        object
# Length: 157, dtype: object

# %%
dtypes_mapping = {
    "_my_subclass": "category",
    "action": "category",
    "active": "bool",
    "all_students": "bool",
    "begin_date": "datetime64",
    "context.is_correct": "bool",
    "visible": "bool",
    "show_email": "category",
    "show_window": "bool",
    "start_time": "datetime64",
    "update_date": "datetime64"
}

# %%
for column in dtypes_mapping.keys():
    df_cleaned[column] = df_cleaned[column].astype(dtypes_mapping[column])

# %%
df_cleaned.dtypes
# Out:
# _my_subclass                   category
# action                         category
# active                             bool
# all_students                       bool
# answer                          float64
# begin_date               datetime64[ns]
# brief_description                object
# categories                       object
# category                        float64
# code                             object
# comment                          object
# component                        object
# context                          object
# context.bulletin_id             float64
# context.bulletin_name            object
# context.bulletin_slug            object
# context.category_id             float64
# context.category_name            object
# context.category_slug            object
# context.comment_id               object
# context.condition                object
# context.dependencies             object
# context.goals_id                float64
# context.goals_name               object
# context.goals_slug               object
# context.group_id                float64
# context.group_name               object
# context.group_slug               object
# context.history_page             object
# context.is_correct                 bool
#                               ...
# repository                       object
# resource                         object
# show_email                     category
# show_window                        bool
# slug                             object
# space                           float64
# start_time               datetime64[ns]
# student                         float64
# students                         object
# subject                         float64
# subscribe_begin                  object
# subscribe_end                    object
# tags                             object
# talk                            float64
# task                            float64
# text                             object
# topic                           float64
# type                             object
# update_date              datetime64[ns]
# url                              object
# user_id                         float64
# user_one                        float64
# user_permissions                 object
# user_quest                      float64
# user_two                        float64
# value                           float64
# viewed                           object
# visible                            bool
# model                            object
# pk                               object
# Length: 156, dtype: object

# %%
df_cleaned.to_csv("../../data/privacy_protected_data/cleaned_data.csv")
