# %% [markdown]
# Here I'm going to explore the notification moduel and how they work. First, I need to understand their fields

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
df = pd.read_json("../data/base_22012019.json")

# %%
notifications_df = df[df["model"] == "notifications.notification"]

# %%
notifications_df.shape
# Out:
# (13219, 3)

# %%
notifications_df["fields"].head(10)[34636]
# Out:
# {'meta': None,
#  'task': 1,
#  'user': 8,
#  'level': 3,
#  'viewed': False,
#  'creation_date': '2018-10-28'}

# %% [markdown]
# Uma notificação possui os seguintes campos no log:
# 1. Meta
# 2. User que coleta o id do user para qual a notificação foi enviada
# 3. Level
# 4. Viewed que possui valor de verdadeiro ou falso indicando se a notifcação foi vista ou não pelo usuário
# 5. A data de criação daquela notificação

# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# é preciso extrair as colunas existentes dentro da coluna "fields", para isso, eu vou utilizar a função json_normalize, nativa do pandas.

# %%
def extract_flatten_dataframe(df, column, meta_list):
    df_fields = json_normalize(data=df[column], meta=meta_list)
    df_fields.index = df.index
    return df_fields.join(df, how="outer")

# %%
notification_fields = json_normalize(data=notifications_df["fields"], meta=["meta", "task", "user", "level", "viewed", "creation_date"] )
notification_fields.index = notifications_df.index
notification_df_flatted = notification_fields.join(notifications_df, how="outer")

# %%
notification_df_flatted.sample(10)
# Out:
#       creation_date  level  meta  task  user  viewed  \
# 40795    2018-12-01      3  None    16    92   False
# 42160    2018-12-07      4  None     8    53   False
# 35703    2018-11-09      3  None     2     8   False
# 47437    2019-01-22      1  None    45    29   False
# 35820    2018-11-12      3  None     7    63   False
# 41702    2018-12-05      3  None    17    50   False
# 42703    2018-12-13      3  None    12    34   False
# 43584    2018-12-17      3  None    42    65    True
# 38472    2018-11-22      4  None     8    65   False
# 35289    2018-11-08      3  None     9    41    True
#
#                                                   fields  \
# 40795  {'meta': None, 'task': 16, 'user': 92, 'level'...
# 42160  {'meta': None, 'task': 8, 'user': 53, 'level':...
# 35703  {'meta': None, 'task': 2, 'user': 8, 'level': ...
# 47437  {'meta': None, 'task': 45, 'user': 29, 'level'...
# 35820  {'meta': None, 'task': 7, 'user': 63, 'level':...
# 41702  {'meta': None, 'task': 17, 'user': 50, 'level'...
# 42703  {'meta': None, 'task': 12, 'user': 34, 'level'...
# 43584  {'meta': None, 'task': 42, 'user': 65, 'level'...
# 38472  {'meta': None, 'task': 8, 'user': 65, 'level':...
# 35289  {'meta': None, 'task': 9, 'user': 41, 'level':...
#
#                             model     pk
# 40795  notifications.notification   6302
# 42160  notifications.notification   7727
# 35703  notifications.notification   1070
# 47437  notifications.notification  13084
# 35820  notifications.notification   1187
# 41702  notifications.notification   7249
# 42703  notifications.notification   8310
# 43584  notifications.notification   9231
# 38472  notifications.notification   3889
# 35289  notifications.notification    656

# %%
notification_fields["meta"].value_counts()
# Out:
# 2018-11-11T01:44:00Z    45
# 2018-11-14T12:33:00Z     6
# 2018-12-01T00:00:00Z     4
# 2018-11-27T22:34:00Z     3
# 2018-11-14T23:00:00Z     3
# 2018-11-12T13:33:00Z     3
# 2018-11-11T23:22:00Z     2
# 2018-11-13T15:19:00Z     1
# 2018-11-07T03:40:00Z     1
# 2018-12-02T02:26:00Z     1
# 2018-11-23T14:05:00Z     1
# 2018-11-19T02:30:00Z     1
# 2018-11-07T02:46:00Z     1
# Name: meta, dtype: int64

# %%
notification_fields.dtypes
# Out:
# creation_date    object
# level             int64
# meta             object
# task              int64
# user              int64
# viewed             bool
# dtype: object

# %% [markdown]
# Como dá pra ver o pandas não consegue inferir muito bem os data types das colunas, vou utilizar meu conhecimento sobre elas para colocar valores mais baratos e que correspondem melhor aos seus valores.m

# %%
notification_fields = notification_fields.astype({"level": pd.CategoricalDtype()})

# %%
notification_fields["level"].describe()
# Out:
# count     13219
# unique        4
# top           3
# freq       6554
# Name: level, dtype: int64

# %%
notification_fields.dtypes
# Out:
# creation_date      object
# level            category
# meta               object
# task                int64
# user                int64
# viewed               bool
# dtype: object

# %%
notification_fields.shape
# Out:
# (13219, 6)

# %% [markdown]
# # Users Data
# Como os usuários são o principal objeto de pesquisa deste relatório, eu preciso coletar os IDs deles para juntar as notificações e "dar à um responsável".

# %%
users_df = df[df["model"] == "users.user"]
users_df
# Out:
#                                                   fields       model   pk
# 34528  {'password': 'pbkdf2_sha256$30000$5DROf4Pf3BPR...  users.user    1
# 34529  {'password': 'pbkdf2_sha256$30000$u3Lg5la328P5...  users.user    2
# 34530  {'password': 'pbkdf2_sha256$30000$Tg55KDswGl6t...  users.user    3
# 34531  {'password': 'pbkdf2_sha256$30000$sN16VkfYDIiS...  users.user    4
# 34532  {'password': 'pbkdf2_sha256$30000$x85db28ZviCz...  users.user    6
# 34533  {'password': 'pbkdf2_sha256$30000$YuhP7bGSlXwn...  users.user    7
# 34534  {'password': 'pbkdf2_sha256$30000$l7WAB2nBwfTg...  users.user    8
# 34535  {'password': 'pbkdf2_sha256$30000$DOj6RbuvrpDK...  users.user    9
# 34536  {'password': 'pbkdf2_sha256$30000$wbwdFEajjHed...  users.user   10
# 34537  {'password': 'pbkdf2_sha256$30000$DOPLvJQYYOz4...  users.user   11
# 34538  {'password': 'pbkdf2_sha256$30000$r0DXYWMxRpst...  users.user   12
# 34539  {'password': 'pbkdf2_sha256$30000$eVB9yTrSyNoB...  users.user   13
# 34540  {'password': 'pbkdf2_sha256$30000$FLXUzVWbEoPS...  users.user   14
# 34541  {'password': 'pbkdf2_sha256$30000$fGpIWFIvrMtc...  users.user   15
# 34542  {'password': 'pbkdf2_sha256$30000$osUH62JV9a0m...  users.user   16
# 34543  {'password': 'pbkdf2_sha256$30000$0XRDrMn982oD...  users.user   17
# 34544  {'password': 'pbkdf2_sha256$30000$0fHafKgzVrTL...  users.user   18
# 34545  {'password': 'pbkdf2_sha256$30000$GVcBJQIS4Fe2...  users.user   19
# 34546  {'password': 'pbkdf2_sha256$30000$Z6rbrmqxe4oB...  users.user   20
# 34547  {'password': 'pbkdf2_sha256$30000$xcQ4kVXpvNkK...  users.user   21
# 34548  {'password': 'pbkdf2_sha256$30000$bNxNzsqr4UdD...  users.user   22
# 34549  {'password': 'pbkdf2_sha256$30000$viYQ4wdkEwvx...  users.user   23
# 34550  {'password': 'pbkdf2_sha256$30000$GmDx8dprbKQf...  users.user   24
# 34551  {'password': 'pbkdf2_sha256$30000$sPd4PWFJna1K...  users.user   25
# 34552  {'password': 'pbkdf2_sha256$30000$AM49R7KvG80v...  users.user   26
# 34553  {'password': 'pbkdf2_sha256$30000$pZI3kN2Ap4XY...  users.user   27
# 34554  {'password': 'pbkdf2_sha256$30000$zLQr5zTS8TXc...  users.user   28
# 34555  {'password': 'pbkdf2_sha256$30000$sfkP4cvWhYT6...  users.user   29
# 34556  {'password': 'pbkdf2_sha256$30000$qcZD0jVvUEzm...  users.user   30
# 34557  {'password': 'pbkdf2_sha256$30000$ZLpgpSRGCz0f...  users.user   31
# ...                                                  ...         ...  ...
# 34604  {'password': 'pbkdf2_sha256$30000$n3qyf0P9yiqu...  users.user   78
# 34605  {'password': 'pbkdf2_sha256$30000$NFucAhK5qkpr...  users.user   79
# 34606  {'password': 'pbkdf2_sha256$30000$1DmTsXGyAda0...  users.user   80
# 34607  {'password': 'pbkdf2_sha256$30000$iFkYYPS3z5Ip...  users.user   81
# 34608  {'password': 'pbkdf2_sha256$30000$9hHymjJcwzPo...  users.user   82
# 34609  {'password': 'pbkdf2_sha256$30000$EUigJkiaLRDM...  users.user   83
# 34610  {'password': 'pbkdf2_sha256$30000$TDWS1SMDoXP1...  users.user   84
# 34611  {'password': 'pbkdf2_sha256$30000$SmW5LaY5Wunv...  users.user   85
# 34612  {'password': 'pbkdf2_sha256$30000$RrmtowHoGDcd...  users.user   86
# 34613  {'password': 'pbkdf2_sha256$30000$CtHHWHSWJqgo...  users.user   87
# 34614  {'password': 'pbkdf2_sha256$30000$YqYm8rl0dJ1n...  users.user   88
# 34615  {'password': 'pbkdf2_sha256$30000$ofQhnT1XHv2Z...  users.user   89
# 34616  {'password': 'pbkdf2_sha256$30000$SDoc1KioxQDi...  users.user   91
# 34617  {'password': 'pbkdf2_sha256$30000$obD71HLn8A1a...  users.user   92
# 34618  {'password': 'pbkdf2_sha256$30000$xJox6dblwiFV...  users.user   93
# 34619  {'password': 'pbkdf2_sha256$30000$Tm2neLZXkPL9...  users.user   94
# 34620  {'password': 'pbkdf2_sha256$30000$WQYl60EuBoOW...  users.user   95
# 34621  {'password': 'pbkdf2_sha256$30000$QQsLwI4nekmi...  users.user   96
# 34622  {'password': 'pbkdf2_sha256$30000$8EHPKiZGWGnx...  users.user   97
# 34623  {'password': 'pbkdf2_sha256$30000$X7LgoIWgYU7l...  users.user   98
# 34624  {'password': 'pbkdf2_sha256$30000$gfNzTHSTr2w1...  users.user   99
# 34625  {'password': 'pbkdf2_sha256$30000$BxTfUzhpxx1x...  users.user  100
# 34626  {'password': 'pbkdf2_sha256$30000$Q9hO2SYPjd4m...  users.user  101
# 34627  {'password': 'pbkdf2_sha256$30000$fzbjlxv7e1O7...  users.user  102
# 34628  {'password': 'pbkdf2_sha256$30000$KQpLQoz6YEiQ...  users.user  103
# 34629  {'password': 'pbkdf2_sha256$30000$Bb2lEsRqHfUp...  users.user  104
# 34630  {'password': 'pbkdf2_sha256$30000$VZV8SvfP7joy...  users.user  105
# 34631  {'password': 'pbkdf2_sha256$30000$KyISsPUuJAaw...  users.user  106
# 34632  {'password': 'pbkdf2_sha256$30000$smDWDoCrxFpt...  users.user  107
# 34633  {'password': 'pbkdf2_sha256$30000$YrGX7hxOaDA2...  users.user  108
#
# [106 rows x 3 columns]

# %%
users_df["fields"][34528]
# Out:
# {'password': 'pbkdf2_sha256$30000$5DROf4Pf3BPR$tPd1JbDlLqrUzoY/JcUSfparBrp7n0ERZKWgpfnbG/Y=',
#  'last_login': '2019-01-22T12:36:36.447Z',
#  'is_superuser': True,
#  'email': 'admin@amadeus.br',
#  'username': 'Administrador',
#  'last_name': 'Geral',
#  'social_name': None,
#  'description': '',
#  'image': '',
#  'date_created': '2018-10-19T16:55:27.084Z',
#  'last_update': '2018-11-04T03:31:13.036Z',
#  'show_email': 1,
#  'is_staff': True,
#  'is_active': True,
#  'groups': [],
#  'user_permissions': []}

# %% [markdown]
# # Dicionário dos dados
# 1. Password: Senha criptografada
# 2. Last_Login: a última vez que o usuário logou no sistema
# 3. is_superuser: Significa que o usuário é um super usuário, tem privilégios ou admin.
# 4. email: e-mail pertecente ao usuário
# 5. username: nome que o usuário quer que outros usuários o vejam
# 6. last_name: Sobrenome do usuário
# 7. social_name: Nome social que o usuário quer escolher para ser demonstrado
# 8. description: ?
# 9. image: Caminho para a imagem do usuário
# 10. date_created: Data em que o usuário foi criado
# 11. last_update: a última vez que os dados do usuário foram modificados
# 12. show_email: Uma booleana que informa se o e-mail é visiível para outros usuários
# 13. is_staff: se ele é do tipo admin
# 14. is_active: Se o usuário está ativo, caso sim, ele pode entrar no sistema, senão, é impossível
# 15. groups: Grupos de permissão ao qual esse usuário pertence ("professor", "estudante"...)
# 16. user_permissions = permissões individuais que ele possui ("criar tópico" , "deletar tópico", "editar tópico")

# %%
# fields:  
user_fields = ["password", "last_login", "is_superuser", "email", "username", "last_name", "social_name", "description", 
               "imagem", "date_created", "last_update", "show_email", "is_staff", "is_active", "groups", "user_permissions"]

# %%
user_df_flatten = extract_flatten_dataframe(users_df, column="fields",meta_list=user_fields)

# %% [markdown]
# # Vou remover as seguintes colunas:
# 1. Groups, pois não possui nenhum valor diferente de vazio (ou nulo).

# %%
user_df_flatten["groups"].value_counts()
# Out:
# []    106
# Name: groups, dtype: int64

# %%
user_df_flatten_clean = user_df_flatten.drop(["groups", "fields", "password"], axis=1)

# %%
user_df_flatten_clean.sample(100)
# Out:
#                    date_created  \
# 34554  2018-11-03T13:47:23.529Z
# 34543  2018-11-03T13:41:29.174Z
# 34582  2018-11-03T14:02:23.521Z
# 34595  2018-11-03T14:09:12.499Z
# 34630  2019-01-21T21:53:06.342Z
# 34596  2018-11-03T14:09:46.793Z
# 34533  2018-10-27T18:03:57.447Z
# 34546  2018-11-03T13:43:04.959Z
# 34607  2018-11-03T14:15:18.260Z
# 34557  2018-11-03T13:48:59.418Z
# 34547  2018-11-03T13:43:39.212Z
# 34616  2018-11-07T02:23:05.685Z
# 34528  2018-10-19T16:55:27.084Z
# 34619  2018-11-12T17:25:51.170Z
# 34608  2018-11-03T14:16:02.137Z
# 34600  2018-11-03T14:11:44.063Z
# 34609  2018-11-03T14:16:30.207Z
# 34586  2018-11-03T14:04:20.479Z
# 34597  2018-11-03T14:10:14.279Z
# 34555  2018-11-03T13:47:57.163Z
# 34572  2018-11-03T13:57:16.677Z
# 34563  2018-11-03T13:52:26.880Z
# 34601  2018-11-03T14:12:11.706Z
# 34536  2018-10-27T18:06:14.561Z
# 34628  2018-12-22T15:13:28.027Z
# 34618  2018-11-11T03:14:24.202Z
# 34558  2018-11-03T13:49:33.765Z
# 34530  2018-10-22T18:21:31.704Z
# 34629  2019-01-21T21:13:03.342Z
# 34615  2018-11-04T03:30:23.694Z
# ...                         ...
# 34548  2018-11-03T13:44:11.883Z
# 34574  2018-11-03T13:58:18.321Z
# 34540  2018-11-03T13:39:27.296Z
# 34581  2018-11-03T14:01:56.564Z
# 34587  2018-11-03T14:04:47.788Z
# 34552  2018-11-03T13:46:23.653Z
# 34573  2018-11-03T13:57:46.229Z
# 34590  2018-11-03T14:06:20.776Z
# 34584  2018-11-03T14:03:19.624Z
# 34544  2018-11-03T13:42:02.615Z
# 34568  2018-11-03T13:55:05.720Z
# 34529  2018-10-21T05:32:02.734Z
# 34591  2018-11-03T14:06:53.202Z
# 34606  2018-11-03T14:14:50.828Z
# 34620  2018-11-17T20:12:02.015Z
# 34576  2018-11-03T13:59:17.650Z
# 34545  2018-11-03T13:42:33.441Z
# 34583  2018-11-03T14:02:51.766Z
# 34613  2018-11-03T14:18:35.606Z
# 34569  2018-11-03T13:55:37.386Z
# 34539  2018-11-03T13:38:40.398Z
# 34578  2018-11-03T14:00:23.461Z
# 34625  2018-12-03T12:27:49.357Z
# 34560  2018-11-03T13:50:37.164Z
# 34627  2018-12-19T21:53:12.761Z
# 34594  2018-11-03T14:08:37.773Z
# 34612  2018-11-03T14:18:08.439Z
# 34565  2018-11-03T13:53:26.796Z
# 34579  2018-11-03T14:00:53.215Z
# 34541  2018-11-03T13:40:04.839Z
#
#                                              description  \
# 34554  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34543  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34582  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34595  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34630
# 34596  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34533                          <p>Usuário de testes.</p>
# 34546  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34607  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34557  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34547  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34616
# 34528
# 34619
# 34608  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34600  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34609  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34586  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34597  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34555  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34572  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34563  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34601  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34536                         <p>Usuários de testes.</p>
# 34628
# 34618
# 34558  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34530  <p>Docente vinculado ao Colegiado Acadêmico de...
# 34629
# 34615
# ...                                                  ...
# 34548  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34574  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34540  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34581  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34587  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34552  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34573  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34590  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34584  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34544  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34568  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34529
# 34591  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34606  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34620
# 34576  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34545  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34583  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34613  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34569  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34539  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34578  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34625
# 34560  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34627
# 34594  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34612  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34565  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34579  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
# 34541  <p>\r\n\r\n\r\n\r\n\r\n<style>\r\n<!--table\r\...
#
#                                email                              image  \
# 34554              05200742544@r1.br
# 34543              10773458441@r1.br
# 34582              06238804580@r1.br
# 34595              86157567597@r1.br
# 34630            igor.hh@outlook.com          users/20190120_113542.jpg
# 34596       karinegsantos1@gmail.com  users/IMG_20180727_211040_057.jpg
# 34533                  e2@amadeus.br            users/masculino_04_.jpg
# 34546              02536903583@r1.br                       users/CR.jpg
# 34607              09958033402@r1.br  users/IMG_20180712_230213_502.jpg
# 34557              09933013475@r1.br
# 34547              12228811440@r1.br
# 34616    yandra_oliveira@hotmail.com
# 34528               admin@amadeus.br
# 34619     thamirescamila@hotmail.com
# 34608              08703735443@r1.br
# 34600              06119356193@r1.br
# 34609           rodrigo.fgomes@r1.br         users/2018631154148240.png
# 34586              11136911405@r1.br
# 34597              11391035470@r1.br
# 34555              11261780477@r1.br
# 34572              11207815403@r1.br
# 34563       matheusvitorsg@gmail.com  users/IMG_20180901_192952_922.jpg
# 34601              86042731580@r1.br
# 34536                  e5@amadeus.br              users/feminino_05.jpg
# 34628      marcelohmuccini@gmail.com                    users/mylon.PNG
# 34618  marcosribeirosilva9@gmail.com
# 34558              04993584571@r1.br
# 34530     joao.sedraz@univasf.edu.br                   users/sedraz.jpg
# 34629    robertovitorlgr@hotmail.com
# 34615               fhab@cin.ufpe.br
# ...                              ...                                ...
# 34548              12197489780@r1.br
# 34574              07474021595@r1.br
# 34540              12547002426@r1.br
# 34581              02324578590@r1.br
# 34587              12048255485@r1.br
# 34552              05228647597@r1.br      users/Iphone_05042016_047.JPG
# 34573              03196307573@r1.br
# 34590          jaine-fer@hotmail.com
# 34584              06657653557@r1.br
# 34544              05375733560@r1.br
# 34568              11303369486@r1.br   users/Rearden_Steel_1280x960.jpg
# 34529                egz@cin.ufpe.br                   users/kaneki.jpg
# 34591              10321600479@r1.br
# 34606              05549746573@r1.br
# 34620                  e6@amadeus.br             users/masculino_07.jpg
# 34576              05518698526@r1.br
# 34545              07898664558@r1.br
# 34583              11920808400@r1.br
# 34613              10064048489@r1.br
# 34569              03435361379@r1.br
# 34539              85812398542@r1.br
# 34578              10815661401@r1.br
# 34625    deisee.oliveira@hotmail.com
# 34560              10312179405@r1.br
# 34627      joaocaetanoln@hotmail.com                users/cristiano.jpg
# 34594              08265881401@r1.br
# 34612              10499649427@r1.br
# 34565              04508616518@r1.br
# 34579              86058884586@r1.br
# 34541              06352736599@r1.br
#
#        is_active  is_staff  is_superuser                last_login  \
# 34554       True     False         False  2019-01-20T21:46:25.751Z
# 34543       True     False         False  2019-01-21T18:07:01.743Z
# 34582       True     False         False  2019-01-22T12:52:00.350Z
# 34595       True     False         False  2019-01-21T18:01:36.044Z
# 34630       True     False         False  2019-01-21T21:54:36.406Z
# 34596       True     False         False  2019-01-21T17:10:04.270Z
# 34533       True     False         False  2018-11-21T09:09:51.308Z
# 34546       True     False         False  2019-01-22T11:56:32.166Z
# 34607       True     False         False  2019-01-21T19:33:56.981Z
# 34557       True     False         False  2019-01-21T17:12:37.188Z
# 34547       True     False         False  2019-01-22T13:49:44.659Z
# 34616       True     False         False  2018-11-14T19:59:45.403Z
# 34528       True      True          True  2019-01-22T12:36:36.447Z
# 34619       True     False         False  2018-11-12T17:26:16.923Z
# 34608       True     False         False  2019-01-22T03:02:02.440Z
# 34600       True     False         False  2018-12-10T17:05:58.293Z
# 34609       True     False         False  2019-01-16T18:14:49.429Z
# 34586       True     False         False  2019-01-14T19:06:55.747Z
# 34597       True     False         False  2019-01-21T14:03:48.782Z
# 34555       True     False         False  2018-12-10T16:45:37.323Z
# 34572       True     False         False  2019-01-21T18:49:58.319Z
# 34563       True     False         False  2019-01-22T12:12:15.659Z
# 34601       True     False         False  2018-12-17T20:40:50.286Z
# 34536       True     False         False  2018-12-28T15:36:24.142Z
# 34628       True     False         False  2019-01-18T13:02:43.934Z
# 34618       True     False         False                      None
# 34558       True     False         False  2019-01-21T17:30:40.767Z
# 34530       True     False         False  2019-01-22T13:45:10.245Z
# 34629       True     False         False  2019-01-21T23:35:33.862Z
# 34615       True      True         False  2018-11-05T00:49:08.439Z
# ...          ...       ...           ...                       ...
# 34548       True     False         False  2019-01-21T16:05:02.370Z
# 34574       True     False         False  2019-01-22T13:55:02.243Z
# 34540       True     False         False  2019-01-19T16:14:53.731Z
# 34581       True     False         False  2019-01-21T19:21:14.078Z
# 34587       True     False         False  2019-01-22T00:00:51.460Z
# 34552       True     False         False  2019-01-22T14:12:03.326Z
# 34573       True     False         False  2019-01-21T18:35:42.103Z
# 34590       True     False         False  2019-01-22T12:21:22.560Z
# 34584       True     False         False  2019-01-21T19:31:06.014Z
# 34544       True     False         False  2019-01-21T08:09:17.708Z
# 34568       True     False         False  2019-01-19T17:29:17.167Z
# 34529       True      True         False  2019-01-19T00:28:17.924Z
# 34591       True     False         False  2019-01-21T16:39:07.867Z
# 34606       True     False         False  2019-01-20T23:33:41.164Z
# 34620       True     False         False                      None
# 34576       True     False         False  2018-12-10T14:30:27.719Z
# 34545       True     False         False  2019-01-21T17:14:00.083Z
# 34583       True     False         False  2019-01-15T16:42:24.474Z
# 34613       True     False         False  2019-01-21T21:35:42.836Z
# 34569       True     False         False  2018-12-09T23:38:14.301Z
# 34539       True     False         False  2019-01-21T20:47:57.279Z
# 34578       True     False         False  2018-12-17T19:29:56.309Z
# 34625       True     False         False  2018-12-03T12:27:56.879Z
# 34560       True     False         False  2019-01-21T11:39:39.299Z
# 34627       True     False         False  2019-01-18T14:30:08.579Z
# 34594       True     False         False  2018-11-18T18:39:46.827Z
# 34612       True     False         False  2019-01-21T19:02:46.007Z
# 34565       True     False         False  2019-01-21T16:37:32.635Z
# 34579       True     False         False  2018-12-21T00:41:59.630Z
# 34541       True     False         False  2018-12-11T16:11:43.967Z
#
#                last_name               last_update  show_email  \
# 34554                  .  2018-11-03T13:47:23.564Z           1
# 34543                  .  2018-11-03T13:41:29.207Z           1
# 34582                  .  2018-11-03T14:02:23.555Z           1
# 34595                  .  2018-11-03T14:09:12.540Z           1
# 34630               Lima  2019-01-21T21:53:06.868Z           1
# 34596                  .  2018-11-09T14:23:27.136Z           1
# 34533                  .  2018-11-17T20:09:57.884Z           1
# 34546                  .  2018-11-11T22:33:44.486Z           1
# 34607                  .  2018-12-11T17:07:58.285Z           1
# 34557                  .  2018-11-03T13:48:59.451Z           1
# 34547                  .  2018-11-03T13:43:39.245Z           1
# 34616           Oliveira  2018-11-07T02:23:05.721Z           1
# 34528              Geral  2018-11-04T03:31:13.036Z           1
# 34619            Tavares  2018-11-12T17:25:51.313Z           1
# 34608                  .  2018-11-03T14:16:02.183Z           1
# 34600                  .  2018-11-03T14:11:44.098Z           1
# 34609                  .  2018-11-05T23:18:10.626Z           1
# 34586                  .  2018-11-03T14:04:20.514Z           1
# 34597                  .  2018-11-03T14:10:14.313Z           1
# 34555                  .  2018-11-03T13:47:57.197Z           1
# 34572                  .  2018-11-03T13:57:16.710Z           1
# 34563                  .  2018-11-07T16:02:02.546Z           1
# 34601                  .  2018-11-03T14:12:11.746Z           1
# 34536                  .  2018-11-17T20:08:29.932Z           1
# 34628            Muccini  2018-12-22T15:13:28.139Z           1
# 34618            Ribeiro  2018-11-11T03:14:24.332Z           1
# 34558                  .  2018-11-03T13:49:33.799Z           1
# 34530              Silva  2018-12-06T12:03:28.281Z           1
# 34629          Rodrigues  2019-01-21T21:13:03.409Z           1
# 34615                  .  2018-11-04T03:30:23.750Z           1
# ...                  ...                       ...         ...
# 34548                  .  2018-11-03T13:44:11.922Z           1
# 34574                  .  2018-12-07T12:42:52.442Z           1
# 34540                  .  2018-11-03T13:39:27.330Z           1
# 34581                  .  2018-11-03T14:01:56.597Z           1
# 34587                  .  2018-11-03T14:04:47.822Z           1
# 34552                  .  2019-01-19T02:13:23.766Z           1
# 34573                  .  2018-11-03T13:57:46.263Z           1
# 34590                  .  2018-11-06T14:41:19.229Z           1
# 34584                  .  2018-11-03T14:03:19.657Z           1
# 34544                  .  2018-11-03T13:42:02.648Z           1
# 34568                  .  2018-11-10T00:35:12.292Z           1
# 34529             Zambom  2018-10-22T14:00:03.256Z           1
# 34591                  .  2018-11-03T14:06:53.236Z           1
# 34606                  .  2018-11-03T14:14:50.861Z           1
# 34620                  .  2018-11-17T20:12:02.103Z           1
# 34576                  .  2018-11-03T13:59:17.685Z           1
# 34545                  .  2018-11-03T13:42:33.477Z           1
# 34583                  .  2018-11-03T14:02:51.801Z           1
# 34613                  .  2018-11-03T14:18:35.642Z           1
# 34569                  .  2018-11-03T13:55:37.423Z           1
# 34539                  .  2018-11-03T13:38:40.431Z           1
# 34578                  .  2018-11-03T14:00:23.494Z           1
# 34625  Silva de Oliveira  2018-12-03T12:27:49.426Z           1
# 34560                  .  2018-11-03T13:50:37.225Z           1
# 34627             Aveiro  2019-01-17T22:57:30.202Z           1
# 34594                  .  2018-11-03T14:08:37.806Z           1
# 34612                  .  2018-11-03T14:18:08.474Z           1
# 34565                  .  2018-11-03T13:53:26.830Z           1
# 34579                  .  2018-11-03T14:00:53.257Z           1
# 34541                  .  2018-11-03T13:40:04.873Z           1
#
#                                      social_name user_permissions  \
# 34554                         IARA DE DEUS SILVA               []
# 34543           BRUNA LARISSA PEIXOTO DOS SANTOS               []
# 34582                    DEISE SILVA DE OLIVEIRA               []
# 34595                         KAREN AKEMI OTSUKA               []
# 34630                                       Igor               []
# 34596                               Karine Gomes               []
# 34533                            Matheus Gabriel               []
# 34546                CARLOS RAMON NUNES DA SILVA               []
# 34607                 RANIELE CAVALCANTI MIRANDA               []
# 34557                   JORGE DE SOUSA RODRIGUES               []
# 34547                   DENILSON DA SILVA VIEIRA               []
# 34616                                     Yandra               []
# 34528                                       None               []
# 34619                                   Thamires               []
# 34608                     RICARDO ANDRADE MACEDO               []
# 34600          LUCIANO DOS SANTOS MIRANDA JUNIOR               []
# 34609                                    Rodrigo               []
# 34586                   GARDENIA NOGUEIRA CAMPOS               []
# 34597                   KEZIA BRASILINO DE SOUZA               []
# 34555                JACKELINE CASTRO DE ALENCAR               []
# 34572            VICTOR EDUARDO FURTADO DE SOUSA               []
# 34563                                      Vitor               []
# 34601           MARCELO HENRIQUE MUCCINI BOTELHO               []
# 34536                                   Angélica               []
# 34628                                      Mylon               []
# 34618                            Marcos Vinicius               []
# 34558      JOSE NEWTON GONCALVES DE SOUZA JUNIOR               []
# 34530                                João Sedraz               []
# 34629                                                          []
# 34615                             Felipe Bormann               []
# ...                                          ...              ...
# 34548               ELIS FERNANDA OLIVEIRA SILVA               []
# 34574       YANDRA BEATRIZ DE OLIVEIRA GONCALVES               []
# 34540             ANTONIO VALENTIM ROCHA RIBEIRO               []
# 34581                    CAIQUE DA SILVA ALENCAR               []
# 34587                   HELEN DE OLIVEIRA COELHO               []
# 34552                      HIAGO TEIXEIRA BAVOSA               []
# 34573                      VINICIUS SILVA SANTOS               []
# 34590                       JAINE FERREIRA SOUSA               []
# 34584                  ENACK VICTOR FRANCA COSTA               []
# 34544          BRUNA RODRIGUES CORDEIRO DA SILVA               []
# 34568                    ROBERTO PESQUEIRA BRITO               []
# 34529                                                          []
# 34591                   JAMILLY GARCIA GONCALVES               []
# 34606                  RAFAELA FERREIRA DA SILVA               []
# 34620                                   Fernando               []
# 34576                      YTALO GUIRRA DE BRITO               []
# 34545                   CAIO EIJI MIZUKI IDOGAWA               []
# 34583                       EMANOEL BARBOSA LIMA               []
# 34613             VALMIR ANTONIO DA SILVA JUNIOR               []
# 34569                  SABRINA RODRIGUES NAZARIO               []
# 34539                  ANTONIO PEDRO GOIS MATIAS               []
# 34578                   ALLAN ANDRADE GOMES LIMA               []
# 34625                                      Deise               []
# 34560              LUCAS PADILHA DE ARAUJO COSTA               []
# 34627                                        CR7               []
# 34594  JUSSARA CHAYENNE ARAUJO DA SILVA MENDONÇA               []
# 34612                      TIAGO DE MACEDO SOUZA               []
# 34565               PAULO HENRIQUE CARNEIRO LIMA               []
# 34579                 ALLYSON KAIC SILVA BATISTA               []
# 34541                        BRENDO SANTOS SILVA               []
#
#                                         username       model   pk
# 34554                         IARA DE DEUS SILVA  users.user   28
# 34543           BRUNA LARISSA PEIXOTO DOS SANTOS  users.user   17
# 34582                    DEISE SILVA DE OLIVEIRA  users.user   56
# 34595                         KAREN AKEMI OTSUKA  users.user   69
# 34630                                       Igor  users.user  105
# 34596                        KARINE GOMES SANTOS  users.user   70
# 34533                               Estudante 02  users.user    7
# 34546                CARLOS RAMON NUNES DA SILVA  users.user   20
# 34607                 RANIELE CAVALCANTI MIRANDA  users.user   81
# 34557                   JORGE DE SOUSA RODRIGUES  users.user   31
# 34547                   DENILSON DA SILVA VIEIRA  users.user   21
# 34616                                     Yandra  users.user   91
# 34528                              Administrador  users.user    1
# 34619                                   Thamires  users.user   94
# 34608                     RICARDO ANDRADE MACEDO  users.user   82
# 34600          LUCIANO DOS SANTOS MIRANDA JUNIOR  users.user   74
# 34609                     RODRIGO FERREIRA GOMES  users.user   83
# 34586                   GARDENIA NOGUEIRA CAMPOS  users.user   60
# 34597                   KEZIA BRASILINO DE SOUZA  users.user   71
# 34555                JACKELINE CASTRO DE ALENCAR  users.user   29
# 34572            VICTOR EDUARDO FURTADO DE SOUSA  users.user   46
# 34563               MATHEUS VITOR DA SILVA GOMES  users.user   37
# 34601           MARCELO HENRIQUE MUCCINI BOTELHO  users.user   75
# 34536                               Estudante 05  users.user   10
# 34628                                     Marelo  users.user  103
# 34618                                     Marcos  users.user   93
# 34558      JOSE NEWTON GONCALVES DE SOUZA JUNIOR  users.user   32
# 34530                         João Carlos Sedraz  users.user    3
# 34629                                    Roberto  users.user  104
# 34615         Felipe Henrique de Almeida Bormann  users.user   89
# ...                                          ...         ...  ...
# 34548               ELIS FERNANDA OLIVEIRA SILVA  users.user   22
# 34574       YANDRA BEATRIZ DE OLIVEIRA GONCALVES  users.user   48
# 34540             ANTONIO VALENTIM ROCHA RIBEIRO  users.user   14
# 34581                    CAIQUE DA SILVA ALENCAR  users.user   55
# 34587                   HELEN DE OLIVEIRA COELHO  users.user   61
# 34552                      HIAGO TEIXEIRA BAVOSA  users.user   26
# 34573                      VINICIUS SILVA SANTOS  users.user   47
# 34590                       JAINE FERREIRA SOUSA  users.user   64
# 34584                  ENACK VICTOR FRANCA COSTA  users.user   58
# 34544          BRUNA RODRIGUES CORDEIRO DA SILVA  users.user   18
# 34568                    ROBERTO PESQUEIRA BRITO  users.user   42
# 34529                                       Erik  users.user    2
# 34591                   JAMILLY GARCIA GONCALVES  users.user   65
# 34606                  RAFAELA FERREIRA DA SILVA  users.user   80
# 34620                               Estudante 06  users.user   95
# 34576                      YTALO GUIRRA DE BRITO  users.user   50
# 34545                   CAIO EIJI MIZUKI IDOGAWA  users.user   19
# 34583                       EMANOEL BARBOSA LIMA  users.user   57
# 34613             VALMIR ANTONIO DA SILVA JUNIOR  users.user   87
# 34569                  SABRINA RODRIGUES NAZARIO  users.user   43
# 34539                  ANTONIO PEDRO GOIS MATIAS  users.user   13
# 34578                   ALLAN ANDRADE GOMES LIMA  users.user   52
# 34625                                      Deise  users.user  100
# 34560              LUCAS PADILHA DE ARAUJO COSTA  users.user   34
# 34627                          Cristiano Ronaldo  users.user  102
# 34594  JUSSARA CHAYENNE ARAUJO DA SILVA MENDONÇA  users.user   68
# 34612                      TIAGO DE MACEDO SOUZA  users.user   86
# 34565               PAULO HENRIQUE CARNEIRO LIMA  users.user   39
# 34579                 ALLYSON KAIC SILVA BATISTA  users.user   53
# 34541                        BRENDO SANTOS SILVA  users.user   15
#
# [100 rows x 16 columns]

# %% [markdown]
# # Junção entre usuários e notificações
# Para otimizar, irei coletar somente o username dos usuários durante o join com as notificações, depois eu irei buscar mais informações sobre eles.m
